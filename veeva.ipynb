# %%
from tweet_scraper import *

# %%
twitter.open('https://twitter.com/veevasystems')
# Out:
# {'status': True}

# %%
veeva_tweets = []

# %%
for i in range(0, 600):
    response = twitter.get_tweets()
    data = response['body']
    for tweet in data:
        veeva_tweets.append(tweet)
    twitter.scroll()
# Out:
# ...
# Progress:   0%|          | 0/200 [00:00<?, ?it/s]
#
# Progress:   0%|          | 0/200 [00:00<?, ?it/s]
#
#
# ...
# Progress: 100%|██████████| 200/200 [00:04<00:00, 49.77it/s]
#
# Progress:   0%|          | 0/200 [00:00<?, ?it/s]
#
#
#
# Progress: 100%|██████████| 200/200 [00:04<00:00, 49.51it/s]
#
#
#
# ...
# Progress: 100%|██████████| 200/200 [00:02<00:00, 99.53it/s]
#
#
# Progress: 100%|██████████| 200/200 [00:04<00:00, 49.67it/s]
#
# Progress:   0%|          | 0/200 [00:00<?, ?it/s]
#
# Progress: 100%|██████████| 200/200 [00:02<00:00, 99.55it/s]
#
# ...
# Progress:   0%|          | 0/200 [00:00<?, ?it/s]
#
#
#
# Progress: 100%|██████████| 200/200 [00:04<00:00, 49.57it/s]
#
#
# Progress: 100%|██████████| 200/200 [00:02<00:00, 99.21it/s]
#
# Progress:   0%|          | 0/200 [00:00<?, ?it/s]
#
# Progress:   0%|          | 0/200 [00:00<?, ?it/s]
#
#
# ...
# Progress: 100%|██████████| 200/200 [00:02<00:00, 99.09it/s]
#
#
# Progress: 100%|██████████| 200/200 [00:02<00:00, 98.44it/s]
#
# ...

# %%
print(len(data))
# Out:
# 8

# %%
veeva_tweets[0]
# Out:
# {'Tweet': 'New research reveals more CROs are taking action to meet the urgent need for faster #clinicaltrials. Read the news: https://bit.ly/3096qT1'}

# %%
len(veeva_tweets)
# Out:
# 1182

# %%
veeva_tweets[949]
# Out:
# {'Tweet': 'Groups across the Bio-IT World community, including Veeva, are offering their services and tools for free to teams working on #coronavirus diagnostics and treatments. https://bit.ly/33LE0zx @bioitworld'}
